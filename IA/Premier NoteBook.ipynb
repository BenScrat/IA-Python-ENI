# %% [markdown]
# # Test Notbook
#
# ## Mon premier sous-titre

# %%
a = 4
b = 5
print(a+b)

# %% [markdown]
# **texte en gras**
#
# *texte en italique*

# %%
print(a)
# Out:
# 4

# %%
liste1 = [1,2,3]
liste2= [2,3,4]
liste1+liste2
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
import numpy as np

liste1 = np.array([1,2,3])
liste2= np.array([2,3,4])
liste1+liste2
# Out:
# array([3, 5, 7])

# %% [markdown]
# ## Affichage du fichier vsc via pandas

# %%
import pandas as pd

iris = pd.read_csv("iris.csv")
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Affichage d'une colonne

# %%
iris['variety']
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %% [markdown]
# ## Affichage de deux collonnes

# %%
iris[['sepal.length', 'sepal.width']]
# Out:
#      sepal.length  sepal.width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# ## Affichage avec restriction

# %%
iris[(iris['petal.length'] < 1.4) & (iris['petal.width'] < 0.3)]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 2            4.7          3.2           1.3          0.2  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 22           4.6          3.6           1.0          0.2  Setosa
# 35           5.0          3.2           1.2          0.2  Setosa
# 36           5.5          3.5           1.3          0.2  Setosa
# 38           4.4          3.0           1.3          0.2  Setosa
# 42           4.4          3.2           1.3          0.2  Setosa

# %% [markdown]
# ## Group by

# %%
iris.groupby('variety').size()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# dtype: int64

# %%
iris.groupby('variety')['petal.length'].mean()
# Out:
# variety
# Setosa        1.462
# Versicolor    4.260
# Virginica     5.552
# Name: petal.length, dtype: float64

# %% [markdown]
# ## Info

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Description

# %%
iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Shape

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Nombre de ligne

# %%
iris.shape[1]
# Out:
# 5

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

plt.plot(iris['sepal.length'], iris['sepal.width'], marker='o', linestyle='', color='m')
plt.xlabel('Longueur du sepal')
plt.ylabel('Largeur du sepal')
plt.title('Largeur du sepal en fonction de la longueur du sepal')
# Out:
# Text(0.5, 1.0, 'Largeur du sepal en fonction de la longueur du sepal')

# %%
iris_setosa = iris[iris['variety']== 'Setosa']
iris_virginica = iris[iris['variety']== 'Virginica']
iris_versicolor = iris[iris['variety']== 'Versicolor']

plt.plot(iris_setosa['sepal.length'], iris_setosa['sepal.width'], marker='1', linestyle='', color='m', label='Setosa')
plt.plot(iris_virginica['sepal.length'], iris_virginica['sepal.width'], marker='+', linestyle='', color='k', label='Virginica')
plt.plot(iris_versicolor['sepal.length'], iris_versicolor['sepal.width'], marker='x', linestyle='', color='r', label='Versicolor')
plt.xlabel('Longueur du sepal')
plt.ylabel('Largeur du sepal')
plt.legend()
plt.title('Largeur du sepal en fonction de la longueur du sepal')
# Out:
# Text(0.5, 1.0, 'Largeur du sepal en fonction de la longueur du sepal')

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

subplot1 = axes[0]
subplot1.plot(iris['sepal.width'], iris['sepal.length'], marker='1', linestyle='', color='m')
subplot1.set_xlabel('Longueur du sepal')
subplot1.set_ylabel('Largeur du sepal')
subplot1.set_title('Longueur du sepal en fonction de la largeur du sepal')

subplot2 = axes[1]
subplot2.plot(iris['petal.width'], iris['petal.length'], marker='1', linestyle='', color='m')
subplot2.set_xlabel('Longueur du petal')
subplot2.set_ylabel('Largeur du petal')
subplot2.set_title('Longueur du patal en fonction de la largeur du petal')
# Out:
# Text(0.5, 1.0, 'Longueur du patal en fonction de la largeur du petal')

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

sns.scatterplot(data=iris, x='sepal.length', y='sepal.width', hue='variety')
# Out:
# <Axes: xlabel='sepal.length', ylabel='sepal.width'>

# %%
sns.pairplot(data=iris, hue='variety')
# Out:
# C:\Users\bvannier2021\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bvannier2021\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bvannier2021\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
